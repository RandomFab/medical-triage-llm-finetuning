# %%
from pathlib import Path

ROOT_DIR = Path().resolve().parent.parent

# %%
# quantization_config = BitsAndBytesConfig(load_in_4bit=True,bnb_4bit_quant_type="nf4", bnb_4bit_use_double_quant=True,bnb_4bit_compute_dtype=torch.bfloat16)
# model_4bit = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-1.7B-Base",quantization_config=quantization_config, dtype="auto", device_map="auto")

# %%
# with open(ROOT_DIR / "params.yaml", "r") as f:
#     config = yaml.safe_load(f)['lora_config']

# lora_config = LoraConfig(
#     task_type=config['task_type'],
#     r=config['r'],
#     lora_alpha=config['lora_alpha'],
#     lora_dropout=config['lora_dropout'],
#     target_modules=config['target_modules']
# )

# model = get_peft_model(model_4bit, lora_config)
# model.print_trainable_parameters()

# %%
import pandas as pd
df = pd.read_parquet(ROOT_DIR / "data/processed/dpo_dataset/dpo_train.parquet")
df.head()
# Out:
#                                             question  \
# 0  employ isotopic signatures to infer the fluctu...
# 1  treatment of choice in saddle nose is?\n\na. a...
# 2  good afternoon, i have been experiencing numbn...
# 3  context: the objective of this systematic revi...
# 4  during the luteal phase of the menstrual cycle...
#
#                                               chosen  \
# 0  analyzing isotopic signatures from archaeologi...
# 1  saddle nose is a condition where there is a no...
# 2  i'm sorry to hear about the discomfort you're ...
# 3  \n\nthe question asks if the tissue engineerin...
# 4  during the luteal phase of the menstrual cycle...
#
#                                             rejected language   question_type  \
# 0  to understand the dietary practices of mesolit...       en  conversational
# 1   saddle nose deformity is a condition where th...       en  conversational
# 2   i am not a doctor, but i can provide you with...       en  conversational
# 3  let's break down the question and the context ...       en  conversational
# 4  \n\nduring the luteal phase of the menstrual c...       en  conversational
#
#   confidence_level dataset_name  token_count_question  token_count_chosen  \
# 0              low     ultramed                    73                 719
# 1              low     ultramed                    22                 234
# 2              low     ultramed                   184                 471
# 3              low     ultramed                   310                 173
# 4              low     ultramed                   108                 353
#
#    token_count_rejected
# 0                   624
# 1                   233
# 2                   326
# 3                   217
# 4                   114

# %%
df.describe(include='all')
# Out:
#                                                  question  \
# count                                                3499
# unique                                               3478
# top     what are the genetic changes related to legius...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    chosen  \
# count                                                3499
# unique                                               3497
# top     to deduce the likely enzymatic activity exhibi...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  rejected language  \
# count                                                3499     3499
# unique                                               3497        1
# top     i'm so sorry to hear that you're still experie...       en
# freq                                                    2     3499
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#          question_type confidence_level dataset_name  token_count_question  \
# count             3499             3499         3499           3499.000000
# unique               1                1            1                   NaN
# top     conversational              low     ultramed                   NaN
# freq              3499             3499         3499                   NaN
# mean               NaN              NaN          NaN            107.138039
# std                NaN              NaN          NaN             82.439881
# min                NaN              NaN          NaN              7.000000
# 25%                NaN              NaN          NaN             55.000000
# 50%                NaN              NaN          NaN             83.000000
# 75%                NaN              NaN          NaN            135.000000
# max                NaN              NaN          NaN            656.000000
#
#         token_count_chosen  token_count_rejected
# count          3499.000000           3499.000000
# unique                 NaN                   NaN
# top                    NaN                   NaN
# freq                   NaN                   NaN
# mean            455.161761            399.444984
# std             229.335218            241.475122
# min              43.000000              6.000000
# 25%             272.000000            201.000000
# 50%             402.000000            331.000000
# 75%             649.000000            594.000000
# max            1758.000000           1800.000000
