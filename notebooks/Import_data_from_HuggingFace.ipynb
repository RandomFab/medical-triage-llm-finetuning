# %% [markdown]
# #Import des datasets huggingface dans Google Cloud Storage

# %%
from datasets import load_dataset
from google.cloud import storage

# %% [markdown]
# ## Import : **frenchmedmcqa**

# %%
frenchmedmcqa_dataset = load_dataset('nthngdy/frenchmedmcqa')

# %%
print(frenchmedmcqa_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'number_correct_answers'],
#         num_rows: 595
#     })
#     validation: Dataset({
#         features: ['id', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'number_correct_answers'],
#         num_rows: 164
#     })
#     test: Dataset({
#         features: ['id', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'number_correct_answers'],
#         num_rows: 321
#     })
# })

# %%
frenchmedmcqa_dataset.save_to_disk("gs://p14-medical-data/raw_data/frenchmedmcqa_dataset")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/321 [00:00<?, ? examples/s]

# %% [markdown]
# ## Import : **MediQAL**

# %% [markdown]
# ### MCQU : multi-choice question / unique correct answser

# %%
mcqu_mediqal_dataset = load_dataset('ANR-MALADES/MediQAl', "mcqu")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
print(mcqu_mediqal_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'clinical_case', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'task', 'medical_subject', 'question_type'],
#         num_rows: 10113
#     })
#     validation: Dataset({
#         features: ['id', 'clinical_case', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'task', 'medical_subject', 'question_type'],
#         num_rows: 2561
#     })
#     test: Dataset({
#         features: ['id', 'clinical_case', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'task', 'medical_subject', 'question_type'],
#         num_rows: 4343
#     })
# })

# %%
mcqu_mediqal_dataset.save_to_disk("gs://p14-medical-data/raw_data/mediqal_datasets/mcqu_medical")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/4343 [00:00<?, ? examples/s]

# %% [markdown]
# ### MCQM : multi-choice question / multi correct answsers

# %%
mcqm_mediqal_dataset = load_dataset('ANR-MALADES/MediQAl', "mcqm")

# %%
print(mcqm_mediqal_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'clinical_case', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'task', 'medical_subject', 'question_type'],
#         num_rows: 5767
#     })
#     validation: Dataset({
#         features: ['id', 'clinical_case', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'task', 'medical_subject', 'question_type'],
#         num_rows: 1466
#     })
#     test: Dataset({
#         features: ['id', 'clinical_case', 'question', 'answer_a', 'answer_b', 'answer_c', 'answer_d', 'answer_e', 'correct_answers', 'task', 'medical_subject', 'question_type'],
#         num_rows: 3384
#     })
# })

# %%
mcqm_mediqal_dataset.save_to_disk("gs://p14-medical-data/raw_data/mediqal_datasets/mcqm_medical")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/3384 [00:00<?, ? examples/s]

# %% [markdown]
# ### OEQ : Open Ended Question with Short Answer

# %%
oeq_mediqal_dataset = load_dataset('ANR-MALADES/MediQAl', "oeq")

# %%
print(oeq_mediqal_dataset)
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['id', 'clinical_case', 'cc_question_number', 'question', 'answer', 'medical_subject', 'question_type'],
#         num_rows: 4969
#     })
# })

# %%
oeq_mediqal_dataset.save_to_disk("gs://p14-medical-data/raw_data/mediqal_datasets/oeq_medical")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/4969 [00:00<?, ? examples/s]

# %% [markdown]
# ## Import : **MedQuad-MedicalQnADataset**

# %%
MedQuad_dataset = load_dataset('keivalya/MedQuad-MedicalQnADataset')

# %%
print(MedQuad_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['qtype', 'Question', 'Answer'],
#         num_rows: 16407
#     })
# })

# %%
MedQuad_dataset.save_to_disk("gs://p14-medical-data/raw_data/MedQuad_dataset")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/16407 [00:00<?, ? examples/s]

# %% [markdown]
# ## Import : **UltraMedical_dataset**

# %%
UltraMedical_dataset = load_dataset('TsinghuaC3I/UltraMedical-Preference')
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data/train.json:   0%|          | 0.00/994M [00:00<?, ?B/s]
# data/dev.json:   0%|          | 0.00/20.2M [00:00<?, ?B/s]
# test.json: 0.00B [00:00, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
print(UltraMedical_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt_id', 'label_type', 'prompt', 'chosen', 'rejected', 'metadata', 'feedback'],
#         num_rows: 109353
#     })
#     validation: Dataset({
#         features: ['prompt_id', 'label_type', 'prompt', 'chosen', 'rejected', 'metadata', 'feedback'],
#         num_rows: 2232
#     })
#     test: Dataset({
#         features: ['prompt_id', 'label_type', 'prompt', 'chosen', 'rejected', 'metadata', 'feedback'],
#         num_rows: 777
#     })
# })

# %%
UltraMedical_dataset.save_to_disk("gs://p14-medical-data/raw_data/UltraMedical_dataset")
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/777 [00:00<?, ? examples/s]
