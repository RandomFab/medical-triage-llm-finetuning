# %% [markdown]
# # EXPLORATION

# %%
import pandas as pd
from datasets import load_dataset
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_parquet("gs://p14-medical-data/processed_data/sft_dataset/sft_dataset.parquet")
df.head(50)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                 question                                                                                                                            answer
# ...
